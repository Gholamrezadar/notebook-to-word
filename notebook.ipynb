# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1

# %% [markdown]
# این تابع برای ساختن فلان است
#
# بیبسبس

# %%
2*2
# Out:
# 4

# %% [markdown]
# ### A

# %%
plt.figure()
plt.plot([1, 2, 3, 4], [1, 2, 3, 4])
plt.show()

plt.figure()
plt.plot([1, 2, 3, 4], [1, 2, 3, 4], c="r")
plt.show()

print("fhjdhfjks")
# Out:
# fhjdhfjks

# %% [markdown]
# ## Part 2

# %% [markdown]
# این تابع برای ساختن فلان2 است
#
# بیبسبس

# %% [markdown]
# ### A

# %%
plt.figure()
plt.plot([1, 2, 3, 4], [1, 2, 3, 4])
plt.show()

# %% [markdown]
# ### B

# %%
plt.figure()
plt.plot([1, 2, 3, 4], [1, 2, 3, 4])
plt.show()

# %% [markdown]
# ## Part 3

# %%
plt.figure()
plt.plot([1, 2, 3, 4], [1, 2, 3, 4], c='y')
plt.show()

# %%
plt.figure()
plt.plot([1, 2, 3, 4], [1, 2, 3, 4], c='g')
plt.show()
